# %%
import tweepy as tw
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
pip install tweepy
# Out:
# Collecting tweepyNote: you may need to restart the kernel to use updated packages.
#
#   Downloading tweepy-4.10.0-py3-none-any.whl (94 kB)
# Collecting requests<3,>=2.27.0
#   Downloading requests-2.27.1-py2.py3-none-any.whl (63 kB)
# Requirement already satisfied: requests-oauthlib<2,>=1.2.0 in c:\users\sazzad555\anaconda3\lib\site-packages (from tweepy) (1.3.1)
# Requirement already satisfied: oauthlib<4,>=3.2.0 in c:\users\sazzad555\anaconda3\lib\site-packages (from tweepy) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sazzad555\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\sazzad555\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sazzad555\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sazzad555\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (2021.10.8)
# Installing collected packages: requests, tweepy
#   Attempting uninstall: requests
#     Found existing installation: requests 2.26.0
#     Uninstalling requests-2.26.0:
#       Successfully uninstalled requests-2.26.0
# Successfully installed requests-2.27.1 tweepy-4.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.4 requires pathlib, which is not installed.
# anaconda-project 0.10.1 requires ruamel-yaml, which is not installed.

# %%
consumer_key = '9qXTSgG0QqR5s5TkwEGmAEvmf'
consumer_secret = 'EB97LIVMHlmvoPFFxavaBo9RsAuBE8O537NezZhse1CEixF5Cw'
access_token = '1525944886696230912-hyCrmnn8BqAcjtcXdySivlPxD36MTC'
access_token_secret = 'NPSZyBb3ZgUXrz9P9N8yg5wgemOHsWqDb9FHsD5hRkQYd'

# %%
auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth=auth.set_access_token(access_token, access_token_secret)
# Instantiate API
api = tw.API(auth, wait_on_rate_limit=True)

# %%
hashtag = "#presidentialdebate"
querys = tw.Cursor(api.search_tweets, q=hashtag).items(1000)
tweets = [{'Tweet':tweet.text, 'Timestamp':tweet.created_at} for tweet in querys]
print(tweets)
# Out:
# ---------------------------------------------------------------------------
# TweepyException                           Traceback (most recent call last)
# C:\Users\SAZZAD~1\AppData\Local\Temp/ipykernel_6856/3302205939.py in <module>
#       1 hashtag = "#presidentialdebate"
#       2 querys = tw.Cursor(api.search_tweets, q=hashtag).items(1000)
# ----> 3 tweets = [{'Tweet':tweet.text, 'Timestamp':tweet.created_at} for tweet in querys]
#       4 print(tweets)
#
# C:\Users\SAZZAD~1\AppData\Local\Temp/ipykernel_6856/3302205939.py in <listcomp>(.0)
#       1 hashtag = "#presidentialdebate"
#       2 querys = tw.Cursor(api.search_tweets, q=hashtag).items(1000)
# ----> 3 tweets = [{'Tweet':tweet.text, 'Timestamp':tweet.created_at} for tweet in querys]
#       4 print(tweets)
#
# ~\anaconda3\lib\site-packages\tweepy\cursor.py in __next__(self)
#      84
#      85     def __next__(self):
# ---> 86         return self.next()
#      87
#      88     def next(self):
#
# ~\anaconda3\lib\site-packages\tweepy\cursor.py in next(self)
#     284         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     285             # Reached end of current page, get the next page...
# --> 286             self.current_page = next(self.page_iterator)
#     287             while len(self.current_page) == 0:
#     288                 self.current_page = next(self.page_iterator)
#
# ~\anaconda3\lib\site-packages\tweepy\cursor.py in __next__(self)
#      84
#      85     def __next__(self):
# ---> 86         return self.next()
#      87
#      88     def next(self):
#
# ~\anaconda3\lib\site-packages\tweepy\cursor.py in next(self)
#     165
#     166         if self.index >= len(self.results) - 1:
# --> 167             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kwargs)
#     168
#     169             model = ModelParser().parse(
#
# ~\anaconda3\lib\site-packages\tweepy\api.py in wrapper(*args, **kwargs)
#      31         @functools.wraps(method)
#      32         def wrapper(*args, **kwargs):
# ---> 33             return method(*args, **kwargs)
#      34         wrapper.pagination_mode = mode
#      35         return wrapper
#
# ~\anaconda3\lib\site-packages\tweepy\api.py in wrapper(*args, **kwargs)
#      44             kwargs['payload_list'] = payload_list
#      45             kwargs['payload_type'] = payload_type
# ---> 46             return method(*args, **kwargs)
#      47         wrapper.payload_list = payload_list
#      48         wrapper.payload_type = payload_type
#
# ~\anaconda3\lib\site-packages\tweepy\api.py in search_tweets(self, q, **kwargs)
#    1301         .. _Twitter's documentation on the standard search API: https://developer.twitter.com/en/docs/twitter-api/v1/tweets/search/overview
#    1302         """
# -> 1303         return self.request(
#    1304             'GET', 'search/tweets', endpoint_parameters=(
#    1305                 'q', 'geocode', 'lang', 'locale', 'result_type', 'count',
#
# ~\anaconda3\lib\site-packages\tweepy\api.py in request(self, method, endpoint, endpoint_parameters, params, headers, json_payload, parser, payload_list, payload_type, post_data, files, require_auth, return_cursors, upload_api, use_cache, **kwargs)
#     144         # are provided, throw an error.
#     145         if require_auth and not self.auth:
# --> 146             raise TweepyException('Authentication required!')
#     147
#     148         self.cached_result = False
#
# TweepyException: Authentication required!

# %%
pip install pathlib
# Out:
# Requirement already satisfied: pathlib in c:\users\sazzad555\anaconda3\lib\site-packages (1.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install ruamel-yaml
# Out:
# Collecting ruamel-yaml
#   Downloading ruamel.yaml-0.17.21-py3-none-any.whl (109 kB)
# Collecting ruamel.yaml.clib>=0.2.6
#   Downloading ruamel.yaml.clib-0.2.6-cp39-cp39-win_amd64.whl (118 kB)
# Installing collected packages: ruamel.yaml.clib, ruamel-yaml
# Successfully installed ruamel-yaml-0.17.21 ruamel.yaml.clib-0.2.6
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tweepy
# Out:
# Requirement already satisfied: tweepy in c:\users\sazzad555\anaconda3\lib\site-packages (4.10.0)
# Requirement already satisfied: requests<3,>=2.27.0 in c:\users\sazzad555\anaconda3\lib\site-packages (from tweepy) (2.27.1)
# Requirement already satisfied: oauthlib<4,>=3.2.0 in c:\users\sazzad555\anaconda3\lib\site-packages (from tweepy) (3.2.0)
# Requirement already satisfied: requests-oauthlib<2,>=1.2.0 in c:\users\sazzad555\anaconda3\lib\site-packages (from tweepy) (1.3.1)
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: idna<4,>=2.5 in c:\users\sazzad555\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (3.2)
#
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\sazzad555\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sazzad555\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sazzad555\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (2021.10.8)

# %%
df=pd.DataFrame(tweets)
df
# Out:
#                                                 Tweet  \
# 0   RT @WSjp_insight: 1st US #PresidentialDebate 0...
# 1   RT @WSjp_insight: 2nd US #PresidentialDebate a...
# 2   RT @WSjp_insight: 1st US #PresidentialDebate 0...
# 3   RT @WSjp_insight: 1st US #PresidentialDebate'1...
# 4   RT @OfficialMrSeun: Tomorrow is ANOG!! With @D...
# 5   RT @OfficialMrSeun: Tomorrow is ANOG!! With @D...
# 6   Tomorrow is ANOG!! With @DrArotele and I'm gas...
# 7   RT @WSjp_insight: Final(2nd)US🇺🇸#PresidentialD...
# 8   RT @WSjp_insight: 3rd US #PresidentialDebate a...
# 9   RT @WSjp_insight: 1st US #PresidentialDebate 0...
# 10  RT @WSjp_insight: 1st US #PresidentialDebate'1...
# 11  RT @WSjp_insight: Final(2nd)US🇺🇸#PresidentialD...
# 12  RT @WSjp_insight: 3rd US #PresidentialDebate a...
# 13  UMA Election Debate @kingsaha256 @IamCindySany...
# 14  RT @WSjp_insight: 1st US #PresidentialDebate 0...
# 15  RT @WSjp_insight: 2nd US #PresidentialDebate a...
# 16  RT @WSjp_insight: 1st US #PresidentialDebate 0...
# 17  RT @WSjp_insight: 1st US #PresidentialDebate'1...
# 18  RT @WSjp_insight: 1st US #PresidentialDebate 0...
# 19  RT @WSjp_insight: 1st US #PresidentialDebate'1...
#
#                    Timestamp
# 0  2022-05-24 13:11:27+00:00
# 1  2022-05-24 13:11:15+00:00
# 2  2022-05-24 13:02:55+00:00
# 3  2022-05-24 13:02:47+00:00
# 4  2022-05-21 21:34:22+00:00
# 5  2022-05-21 19:26:44+00:00
# 6  2022-05-21 19:18:32+00:00
# 7  2022-05-20 14:23:36+00:00
# 8  2022-05-20 14:23:28+00:00
# 9  2022-05-20 14:16:38+00:00
# 10 2022-05-20 14:16:30+00:00
# 11 2022-05-19 14:58:05+00:00
# 12 2022-05-19 14:57:59+00:00
# 13 2022-05-19 11:12:17+00:00
# 14 2022-05-18 14:31:12+00:00
# 15 2022-05-18 14:31:05+00:00
# 16 2022-05-17 13:21:24+00:00
# 17 2022-05-17 13:21:16+00:00
# 18 2022-05-16 14:59:02+00:00
# 19 2022-05-16 14:58:55+00:00

# %%
trump = ['DonaldTrump', 'Donald Trump', 'Donald', 'Trump', 'Trump\'s']
biden = ['JoeBiden', 'Joe Biden', 'Joe', 'Biden', 'Biden\'s']

# %%
def flagging(tweet,refs):
    flag=0
    for ref in refs:
          if tweet.find(ref) !=-1:
            flag=1
    return flag

# %%
df['trump']=df['Tweet'].apply(lambda x:flagging(x,trump))
df['biden']=df['Tweet'].apply(lambda x:flagging(x,biden))

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\SAZZAD~1\AppData\Local\Temp/ipykernel_3288/3883335876.py in <module>
# ----> 1 trumpl=trump.astype('str')
#
# AttributeError: 'list' object has no attribute 'astype'

# %%
import nltk
from nltk.corpus import stopwords
from textblob import Word,TextBlob

# %%
nltk.download('stopwords')
nltk.download('wordnet')
stop_words = stopwords.words('english')
custom_stopwords = ['RT', '#PresidentialDebate']
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sazzad555\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\sazzad555\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
pip install textblob
# Out:
# Collecting textblob
#   Downloading textblob-0.17.1-py2.py3-none-any.whl (636 kB)
# Requirement already satisfied: nltk>=3.1 in c:\users\sazzad555\anaconda3\lib\site-packages (from textblob) (3.6.5)
# Requirement already satisfied: click in c:\users\sazzad555\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (8.0.3)
# Requirement already satisfied: joblib in c:\users\sazzad555\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\sazzad555\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (2021.8.3)
# Requirement already satisfied: tqdm in c:\users\sazzad555\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (4.62.3)
# Requirement already satisfied: colorama in c:\users\sazzad555\anaconda3\lib\site-packages (from click->nltk>=3.1->textblob) (0.4.4)
# Installing collected packages: textblob
# Successfully installed textblob-0.17.1
# Note: you may need to restart the kernel to use updated packages.

# %%
def preprocess(tweet,custom_stop):
    pre=tweet
    pre.replace('[^\w\s]', '')
    pre=''.join(word  for word in pre.split() if  word not in stop_words)
    pre=''.join(word  for word in pre.split() if  word not in custom_stop)
    pre=''.join(Word(word)  for word in pre.split())
    return pre

# %%
df['preTweet']=df['Tweet'].apply(lambda x: preprocess(x,custom_stopwords))
df
# Out:
#                                                 Tweet  \
# 0   RT @WSjp_insight: 1st US #PresidentialDebate 0...
# 1   RT @WSjp_insight: 2nd US #PresidentialDebate a...
# 2   RT @WSjp_insight: 1st US #PresidentialDebate 0...
# 3   RT @WSjp_insight: 1st US #PresidentialDebate'1...
# 4   RT @OfficialMrSeun: Tomorrow is ANOG!! With @D...
# 5   RT @OfficialMrSeun: Tomorrow is ANOG!! With @D...
# 6   Tomorrow is ANOG!! With @DrArotele and I'm gas...
# 7   RT @WSjp_insight: Final(2nd)US🇺🇸#PresidentialD...
# 8   RT @WSjp_insight: 3rd US #PresidentialDebate a...
# 9   RT @WSjp_insight: 1st US #PresidentialDebate 0...
# 10  RT @WSjp_insight: 1st US #PresidentialDebate'1...
# 11  RT @WSjp_insight: Final(2nd)US🇺🇸#PresidentialD...
# 12  RT @WSjp_insight: 3rd US #PresidentialDebate a...
# 13  UMA Election Debate @kingsaha256 @IamCindySany...
# 14  RT @WSjp_insight: 1st US #PresidentialDebate 0...
# 15  RT @WSjp_insight: 2nd US #PresidentialDebate a...
# 16  RT @WSjp_insight: 1st US #PresidentialDebate 0...
# 17  RT @WSjp_insight: 1st US #PresidentialDebate'1...
# 18  RT @WSjp_insight: 1st US #PresidentialDebate 0...
# 19  RT @WSjp_insight: 1st US #PresidentialDebate'1...
#
#                    Timestamp  trump  biden  \
# 0  2022-05-24 13:11:27+00:00      1      1
# 1  2022-05-24 13:11:15+00:00      0      0
# 2  2022-05-24 13:02:55+00:00      0      0
# 3  2022-05-24 13:02:47+00:00      0      0
# 4  2022-05-21 21:34:22+00:00      0      0
# 5  2022-05-21 19:26:44+00:00      0      0
# 6  2022-05-21 19:18:32+00:00      0      0
# 7  2022-05-20 14:23:36+00:00      0      0
# 8  2022-05-20 14:23:28+00:00      0      0
# 9  2022-05-20 14:16:38+00:00      0      0
# 10 2022-05-20 14:16:30+00:00      0      0
# 11 2022-05-19 14:58:05+00:00      0      0
# 12 2022-05-19 14:57:59+00:00      0      0
# 13 2022-05-19 11:12:17+00:00      0      0
# 14 2022-05-18 14:31:12+00:00      1      1
# 15 2022-05-18 14:31:05+00:00      0      0
# 16 2022-05-17 13:21:24+00:00      0      0
# 17 2022-05-17 13:21:16+00:00      0      0
# 18 2022-05-16 14:59:02+00:00      0      0
# 19 2022-05-16 14:58:55+00:00      0      0
#
#                                              preTweet
# 0   RT@WSjp_insight:1stUS#PresidentialDebate09/29/...
# 1   RT@WSjp_insight:2ndUS#PresidentialDebatearticl...
# 2   RT@WSjp_insight:1stUS#PresidentialDebate09/29/...
# 3   RT@WSjp_insight:1stUS#PresidentialDebate'16exc...
# 4   RT@OfficialMrSeun:TomorrowANOG!!With@DrArotele...
# 5   RT@OfficialMrSeun:TomorrowANOG!!With@DrArotele...
# 6   TomorrowANOG!!With@DrAroteleI'mgassedup!Alotco...
# 7   RT@WSjp_insight:Final(2nd)US🇺🇸#PresidentialDeb...
# 8   RT@WSjp_insight:3rdUS#PresidentialDebatearticl...
# 9   RT@WSjp_insight:1stUS#PresidentialDebate09/29/...
# 10  RT@WSjp_insight:1stUS#PresidentialDebate'16exc...
# 11  RT@WSjp_insight:Final(2nd)US🇺🇸#PresidentialDeb...
# 12  RT@WSjp_insight:3rdUS#PresidentialDebatearticl...
# 13  UMAElectionDebate@kingsaha256@IamCindySanyuLiv...
# 14  RT@WSjp_insight:1stUS#PresidentialDebate09/29/...
# 15  RT@WSjp_insight:2ndUS#PresidentialDebatearticl...
# 16  RT@WSjp_insight:1stUS#PresidentialDebate09/29/...
# 17  RT@WSjp_insight:1stUS#PresidentialDebate'16exc...
# 18  RT@WSjp_insight:1stUS#PresidentialDebate09/29/...
# 19  RT@WSjp_insight:1stUS#PresidentialDebate'16exc...

# %%
pre=df['Tweet'][80]
pre
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     384                 try:
# --> 385                     return self._range.index(new_key)
#     386                 except ValueError as err:
#
# ValueError: 80 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# C:\Users\SAZZAD~1\AppData\Local\Temp/ipykernel_3288/1748039418.py in <module>
# ----> 1 pre=df['Tweet'][80]
#       2 pre
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#    1049
#    1050         # Similar to Index.get_value, but we do not fall back to positional
# -> 1051         loc = self.index.get_loc(label)
#    1052         return self.index._get_values_for_loc(self, loc, label)
#    1053
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     385                     return self._range.index(new_key)
#     386                 except ValueError as err:
# --> 387                     raise KeyError(key) from err
#     388             raise KeyError(key)
#     389         return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: 80

# %%
  pre=''.join(word  for word in pre.split() if  word not in custom_stopwords)
pre
# Out:
# '@WSjp_insight:1stUS09/29/2020🇺🇸#Debates2020#TrumpBidenDebatehttps://t.co/DfBnubTidBPBS,NewsHourCBSNewsNBCPo…'

# %%
dir(api)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'add_list_member',
#  'add_list_members',
#  'auth',
#  'available_trends',
#  'cache',
#  'chunked_upload',
#  'chunked_upload_append',
#  'chunked_upload_finalize',
#  'chunked_upload_init',
#  'closest_trends',
#  'create_block',
#  'create_favorite',
#  'create_friendship',
#  'create_list',
#  'create_media_metadata',
#  'create_mute',
#  'create_saved_search',
#  'delete_direct_message',
#  'destroy_block',
#  'destroy_favorite',
#  'destroy_friendship',
#  'destroy_list',
#  'destroy_mute',
#  'destroy_saved_search',
#  'destroy_status',
#  'geo_id',
#  'get_blocked_ids',
#  'get_blocks',
#  'get_direct_message',
#  'get_direct_messages',
#  'get_favorites',
#  'get_follower_ids',
#  'get_followers',
#  'get_friend_ids',
#  'get_friends',
#  'get_friendship',
#  'get_list',
#  'get_list_member',
#  'get_list_members',
#  'get_list_memberships',
#  'get_list_ownerships',
#  'get_list_subscriber',
#  'get_list_subscribers',
#  'get_list_subscriptions',
#  'get_lists',
#  'get_media_upload_status',
#  'get_muted_ids',
#  'get_mutes',
#  'get_oembed',
#  'get_place_trends',
#  'get_profile_banner',
#  'get_retweeter_ids',
#  'get_retweets',
#  'get_retweets_of_me',
#  'get_saved_search',
#  'get_saved_searches',
#  'get_settings',
#  'get_status',
#  'get_user',
#  'home_timeline',
#  'host',
#  'incoming_friendships',
#  'indicate_direct_message_typing',
#  'list_timeline',
#  'lookup_friendships',
#  'lookup_statuses',
#  'lookup_users',
#  'mark_direct_message_read',
#  'media_upload',
#  'mentions_timeline',
#  'no_retweets_friendships',
#  'outgoing_friendships',
#  'parser',
#  'proxy',
#  'rate_limit_status',
#  'remove_list_member',
#  'remove_list_members',
#  'remove_profile_banner',
#  'report_spam',
#  'request',
#  'retry_count',
#  'retry_delay',
#  'retry_errors',
#  'retweet',
#  'reverse_geocode',
#  'search_30_day',
#  'search_full_archive',
#  'search_geo',
#  'search_tweets',
#  'search_users',
#  'send_direct_message',
#  'session',
#  'set_settings',
#  'simple_upload',
#  'subscribe_list',
#  'supported_languages',
#  'timeout',
#  'unretweet',
#  'unsubscribe_list',
#  'update_friendship',
#  'update_list',
#  'update_profile',
#  'update_profile_banner',
#  'update_profile_image',
#  'update_status',
#  'update_status_with_media',
#  'upload_host',
#  'user_agent',
#  'user_timeline',
#  'verify_credentials',
#  'wait_on_rate_limit']

# %%
pip install git+https://github.com/tweepy/tweepy.git
# Out:
# Collecting git+https://github.com/tweepy/tweepy.gitNote: you may need to restart the kernel to use updated packages.
#   Running command git clone -q https://github.com/tweepy/tweepy.git 'C:\Users\sazzad555\AppData\Local\Temp\pip-req-build-izigxzhs'
#   ERROR: Error [WinError 2] The system cannot find the file specified while executing command git clone -q https://github.com/tweepy/tweepy.git 'C:\Users\sazzad555\AppData\Local\Temp\pip-req-build-izigxzhs'
# ERROR: Cannot find command 'git' - do you have 'git' installed and in your PATH?
#   Cloning https://github.com/tweepy/tweepy.git to c:\users\sazzad555\appdata\local\temp\pip-req-build-izigxzhs

# %%
pip install tweepy[async]
# Out:
# Requirement already satisfied: tweepy[async] in c:\users\sazzad555\anaconda3\lib\site-packages (4.10.0)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: oauthlib<4,>=3.2.0 in c:\users\sazzad555\anaconda3\lib\site-packages (from tweepy[async]) (3.2.0)
# Requirement already satisfied: requests-oauthlib<2,>=1.2.0 in c:\users\sazzad555\anaconda3\lib\site-packages (from tweepy[async]) (1.3.1)
# Requirement already satisfied: requests<3,>=2.27.0 in c:\users\sazzad555\anaconda3\lib\site-packages (from tweepy[async]) (2.27.1)
# Collecting aiohttp<4,>=3.7.3
#   Downloading aiohttp-3.8.1-cp39-cp39-win_amd64.whl (554 kB)
# Collecting async-lru<2,>=1.0.3
#
#   Downloading async_lru-1.0.3-py3-none-any.whl (4.3 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp39-cp39-win_amd64.whl (28 kB)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in c:\users\sazzad555\anaconda3\lib\site-packages (from aiohttp<4,>=3.7.3->tweepy[async]) (2.0.4)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp39-cp39-win_amd64.whl (122 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\sazzad555\anaconda3\lib\site-packages (from aiohttp<4,>=3.7.3->tweepy[async]) (21.2.0)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.0-cp39-cp39-win_amd64.whl (33 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sazzad555\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy[async]) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sazzad555\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy[async]) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sazzad555\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy[async]) (3.2)
# Installing collected packages: multidict, frozenlist, yarl, async-timeout, aiosignal, async-lru, aiohttp
# Successfully installed aiohttp-3.8.1 aiosignal-1.2.0 async-lru-1.0.3 async-timeout-4.0.2 frozenlist-1.3.0 multidict-6.0.2 yarl-1.7.2
